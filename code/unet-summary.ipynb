# %% [markdown]
# # U-Net

# %% [markdown]
# ***Summary :***
# - Total params: 599,412
# - Trainable params: 597,620
# - Non-trainable params: 1,792
# - Total Number of Layers: 68
# - Total number of filters in model: 900

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score
from sklearn.metrics import jaccard_score, accuracy_score
import cv2

# %%
model = keras.models.load_model('aerial-unet.h5', compile=False)

# %%
model.summary()
num_layers = len(model.layers)
print("Total Number of Layers:", num_layers)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 1024, 1024,  0
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 1024, 1024, 1 448         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 1024, 1024, 1 64          conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 1024, 1024, 1 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 1024, 1024, 1 2320        activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 1024, 1024, 1 64          conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 1024, 1024, 1 0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 512, 512, 16) 0           activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 512, 512, 32) 4640        max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 512, 512, 32) 128         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 512, 512, 32) 0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 512, 512, 32) 9248        activation_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 512, 512, 32) 128         conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 512, 512, 32) 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 256, 256, 32) 0           activation_93[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 256, 256, 48) 13872       max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 256, 256, 48) 192         conv2d_99[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 256, 256, 48) 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 256, 256, 48) 20784       activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 256, 256, 48) 192         conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 256, 256, 48) 0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 128, 128, 48) 0           activation_95[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 128, 128, 64) 27712       max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 128, 128, 64) 256         conv2d_101[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 128, 128, 64) 0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 128, 128, 64) 36928       activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 128, 128, 64) 256         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 128, 128, 64) 0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 64, 64, 64)   0           activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 64, 64, 128)  73856       max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 64, 64, 128)  512         conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 64, 64, 128)  0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 64, 64, 128)  147584      activation_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 64, 64, 128)  512         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 64, 64, 128)  0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_20 (UpSampling2D) (None, 128, 128, 128 0           activation_99[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 128, 128, 192 0           up_sampling2d_20[0][0]
#                                                                  activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 128, 128, 64) 110656      concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 128, 128, 64) 256         conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 128, 128, 64) 0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 128, 128, 64) 36928       activation_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 128, 128, 64) 256         conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 128, 128, 64) 0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_21 (UpSampling2D) (None, 256, 256, 64) 0           activation_101[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 256, 256, 112 0           up_sampling2d_21[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 256, 256, 48) 48432       concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 256, 256, 48) 192         conv2d_107[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 256, 256, 48) 0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 256, 256, 48) 20784       activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 256, 256, 48) 192         conv2d_108[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 256, 256, 48) 0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_22 (UpSampling2D) (None, 512, 512, 48) 0           activation_103[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 512, 512, 80) 0           up_sampling2d_22[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 512, 512, 32) 23072       concatenate_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 512, 512, 32) 128         conv2d_109[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 512, 512, 32) 0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 512, 512, 32) 9248        activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 512, 512, 32) 128         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 512, 512, 32) 0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_23 (UpSampling2D) (None, 1024, 1024, 3 0           activation_105[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 1024, 1024, 4 0           up_sampling2d_23[0][0]
#                                                                  activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 1024, 1024, 1 6928        concatenate_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 1024, 1024, 1 64          conv2d_111[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 1024, 1024, 1 0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 1024, 1024, 1 2320        activation_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 1024, 1024, 1 64          conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 1024, 1024, 1 0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 1024, 1024, 4 68          activation_107[0][0]
# ==================================================================================================
# Total params: 599,412
# Trainable params: 597,620
# Non-trainable params: 1,792
# __________________________________________________________________________________________________
# Total Number of Layers: 68

# %%
# This will iterate through each layer in the model and print its name, input shape, and output shape. 
for layer in model.layers:
    print(layer.name, layer.input_shape, layer.output_shape)
# Out:
# input_6 [(None, 1024, 1024, 3)] [(None, 1024, 1024, 3)]
# conv2d_95 (None, 1024, 1024, 3) (None, 1024, 1024, 16)
# batch_normalization_90 (None, 1024, 1024, 16) (None, 1024, 1024, 16)
# activation_90 (None, 1024, 1024, 16) (None, 1024, 1024, 16)
# conv2d_96 (None, 1024, 1024, 16) (None, 1024, 1024, 16)
# batch_normalization_91 (None, 1024, 1024, 16) (None, 1024, 1024, 16)
# activation_91 (None, 1024, 1024, 16) (None, 1024, 1024, 16)
# max_pooling2d_20 (None, 1024, 1024, 16) (None, 512, 512, 16)
# conv2d_97 (None, 512, 512, 16) (None, 512, 512, 32)
# batch_normalization_92 (None, 512, 512, 32) (None, 512, 512, 32)
# activation_92 (None, 512, 512, 32) (None, 512, 512, 32)
# conv2d_98 (None, 512, 512, 32) (None, 512, 512, 32)
# batch_normalization_93 (None, 512, 512, 32) (None, 512, 512, 32)
# activation_93 (None, 512, 512, 32) (None, 512, 512, 32)
# max_pooling2d_21 (None, 512, 512, 32) (None, 256, 256, 32)
# conv2d_99 (None, 256, 256, 32) (None, 256, 256, 48)
# batch_normalization_94 (None, 256, 256, 48) (None, 256, 256, 48)
# activation_94 (None, 256, 256, 48) (None, 256, 256, 48)
# conv2d_100 (None, 256, 256, 48) (None, 256, 256, 48)
# batch_normalization_95 (None, 256, 256, 48) (None, 256, 256, 48)
# activation_95 (None, 256, 256, 48) (None, 256, 256, 48)
# max_pooling2d_22 (None, 256, 256, 48) (None, 128, 128, 48)
# conv2d_101 (None, 128, 128, 48) (None, 128, 128, 64)
# batch_normalization_96 (None, 128, 128, 64) (None, 128, 128, 64)
# activation_96 (None, 128, 128, 64) (None, 128, 128, 64)
# conv2d_102 (None, 128, 128, 64) (None, 128, 128, 64)
# batch_normalization_97 (None, 128, 128, 64) (None, 128, 128, 64)
# activation_97 (None, 128, 128, 64) (None, 128, 128, 64)
# max_pooling2d_23 (None, 128, 128, 64) (None, 64, 64, 64)
# conv2d_103 (None, 64, 64, 64) (None, 64, 64, 128)
# batch_normalization_98 (None, 64, 64, 128) (None, 64, 64, 128)
# activation_98 (None, 64, 64, 128) (None, 64, 64, 128)
# conv2d_104 (None, 64, 64, 128) (None, 64, 64, 128)
# batch_normalization_99 (None, 64, 64, 128) (None, 64, 64, 128)
# activation_99 (None, 64, 64, 128) (None, 64, 64, 128)
# up_sampling2d_20 (None, 64, 64, 128) (None, 128, 128, 128)
# concatenate_20 [(None, 128, 128, 128), (None, 128, 128, 64)] (None, 128, 128, 192)
# conv2d_105 (None, 128, 128, 192) (None, 128, 128, 64)
# batch_normalization_100 (None, 128, 128, 64) (None, 128, 128, 64)
# activation_100 (None, 128, 128, 64) (None, 128, 128, 64)
# conv2d_106 (None, 128, 128, 64) (None, 128, 128, 64)
# batch_normalization_101 (None, 128, 128, 64) (None, 128, 128, 64)
# activation_101 (None, 128, 128, 64) (None, 128, 128, 64)
# up_sampling2d_21 (None, 128, 128, 64) (None, 256, 256, 64)
# concatenate_21 [(None, 256, 256, 64), (None, 256, 256, 48)] (None, 256, 256, 112)
# conv2d_107 (None, 256, 256, 112) (None, 256, 256, 48)
# batch_normalization_102 (None, 256, 256, 48) (None, 256, 256, 48)
# activation_102 (None, 256, 256, 48) (None, 256, 256, 48)
# conv2d_108 (None, 256, 256, 48) (None, 256, 256, 48)
# batch_normalization_103 (None, 256, 256, 48) (None, 256, 256, 48)
# activation_103 (None, 256, 256, 48) (None, 256, 256, 48)
# up_sampling2d_22 (None, 256, 256, 48) (None, 512, 512, 48)
# concatenate_22 [(None, 512, 512, 48), (None, 512, 512, 32)] (None, 512, 512, 80)
# conv2d_109 (None, 512, 512, 80) (None, 512, 512, 32)
# batch_normalization_104 (None, 512, 512, 32) (None, 512, 512, 32)
# activation_104 (None, 512, 512, 32) (None, 512, 512, 32)
# conv2d_110 (None, 512, 512, 32) (None, 512, 512, 32)
# batch_normalization_105 (None, 512, 512, 32) (None, 512, 512, 32)
# activation_105 (None, 512, 512, 32) (None, 512, 512, 32)
# up_sampling2d_23 (None, 512, 512, 32) (None, 1024, 1024, 32)
# concatenate_23 [(None, 1024, 1024, 32), (None, 1024, 1024, 16)] (None, 1024, 1024, 48)
# conv2d_111 (None, 1024, 1024, 48) (None, 1024, 1024, 16)
# batch_normalization_106 (None, 1024, 1024, 16) (None, 1024, 1024, 16)
# activation_106 (None, 1024, 1024, 16) (None, 1024, 1024, 16)
# conv2d_112 (None, 1024, 1024, 16) (None, 1024, 1024, 16)
# batch_normalization_107 (None, 1024, 1024, 16) (None, 1024, 1024, 16)
# activation_107 (None, 1024, 1024, 16) (None, 1024, 1024, 16)
# conv2d_113 (None, 1024, 1024, 16) (None, 1024, 1024, 4)

# %%
# Iterate through the model's layers and access their respective filter sizes and counts
fr = 0
for layer in model.layers:
    if hasattr(layer, 'filters'):
        filter_size = layer.kernel_size
        num_filters = layer.filters
        fr = fr + num_filters
        print(f"Layer: {layer.name}")
        print(f"Filter Size: {filter_size}")
        print(f"Total Number of Filters: {num_filters}\n")
print(f"Total number of filters in model: {fr}")

# %%
# Print the type of each layer and its configuration
for layer in model.layers:
    print(f"Layer: {layer.name}")
    print(f"Type: {type(layer).__name__}")
    print(f"Configuration: {layer.get_config()}\n")

# %%
# Print the weights of each layer
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        print(f"Layer: {layer.name}")
        for i, weight_array in enumerate(weights):
            print(f"Weight {i+1}: Shape {weight_array.shape}\n{weight_array}\n")

# %%
print("Model Input Tensors:")
for input_tensor in model.inputs:
    print(input_tensor.name, input_tensor.shape)

print("\nModel Output Tensors:")
for output_tensor in model.outputs:
    print(output_tensor.name, output_tensor.shape)
# Out:
# Model Input Tensors:
# input_6 (None, 1024, 1024, 3)
#
# Model Output Tensors:
# conv2d_113/Softmax:0 (None, 1024, 1024, 4)
